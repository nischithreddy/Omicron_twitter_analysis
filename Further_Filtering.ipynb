# %%
import pandas as pd
import numpy as np
import glob
from datetime import datetime
import os
import re
import string
import nltk

from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

import seaborn as sns
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
px = "/content/drive/MyDrive/IDS 506 Healthcare Analytics/506 Project/IndivFiles/df_ind_11292021.csv"
dfpx = pd.read_csv(px, engine='python')

# %%
print(len(dfpx))
print(len(dfpx['id'].unique()))
print(len(dfpx['user_id'].unique()))
# Out:
# 77998
# 77998
# 52160

# %%
uniq_list = ['news', 'agency', 'official', 'government', 'group', 'media', 'organisation', 'organization', 
             'alliance', '24/7', '24x7','24X7', 'livecast', 'commission', 'business', 'breaking', 'company', 
              'network', 'latest', 'suntimes', 'bostonglobe', 'nwitimes', 'daily',
             'corporation', 'corp' 'inc', 'ltd', 'newsmagazine', 'institution', 'public health', 'times', 'moneycontrol',
             'pib', 'bloomberg', 'world news', 'times']

date1 = '2021-11-21'
date2 = '2022-01-31'

#date1 = datetime.datetime.strptime('12012021', '%m%d%Y')
#date2 = datetime.datetime.strptime('12022021', '%m%d%Y')

mydates = pd.date_range(date1, date2, freq='d')#.tolist()
print(mydates)
for d in pd.date_range(date1, date2, freq='d'):
  d_str = d.strftime("%m%d%Y")
  print(d_str)
  path = "/content/drive/MyDrive/IDS 506 Healthcare Analytics/506 Project/IndivFiles/df_ind_" + d_str + ".csv"

  df = pd.read_csv(path, engine= 'python')
  df_reduced = df[['coordinates', 'created_at', 'hashtags', 'place', 
                   'source','user_id', 'user_description', 'user_name', 'id',
       'user_screen_name', 'user_urls', 'user_verified', 'text', 'ind_org']]

  nltk.download('punkt')
  nltk.download('stopwords')

  STOP_WORDS = stopwords.words()

  # removing the emojies
  # https://www.kaggle.com/alankritamishra/covid-19-tweet-sentiment-analysis#Sentiment-analysis
  EMOJI_PATTERN = re.compile("["
                            u"\U0001F600-\U0001F64F"  # emoticons
                            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                            u"\U0001F680-\U0001F6FF"  # transport & map symbols
                            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                            u"\U00002702-\U000027B0"
                            u"\U000024C2-\U0001F251"
                            "]+", flags=re.UNICODE)


  def cleaning(text):
      """
      Convert to lowercase.
      Rremove URL links, special characters and punctuation.
      Tokenize and remove stop words.
      """
      text = text.lower()
      text = re.sub('https?://\S+|www\.\S+', '', text)
      text = re.sub('@[A-Za-z0-9]+', '', text)
      text = re.sub('<.*?>+', '', text)   # replacing HTML text with blank or whitespace
      text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
      text = re.sub('\n', '', text)
      text = re.sub('[’“”…]', '', text)
      
      text = text.encode("ascii", "ignore")     # consider only english alphanumeric characters
      text = text.decode()
      
      text = EMOJI_PATTERN.sub(r'', text)
    
      
      
      # removing the stop-words
      text_tokens = word_tokenize(text)
      tokens_without_sw = [
        word for word in text_tokens if not word in STOP_WORDS]
      filtered_sentence = (" ").join(tokens_without_sw)
      text = filtered_sentence
      
      return text

  def func2(val1, val2):
    for word in uniq_list:
        if (word in val1):     # may use val2 ie user_verified status for additional filtering
            return "org"
        else:
            return "ind"

  #if __name__ == "__main__":
  #    max_rows = 1000  # 'None' to read whole file
      
  #df = pd.read_csv("Labeled_tweets.csv")
  #df.head()

 
  df_reduced['name_plus_desp'] = df_reduced['user_name'] + " " + df_reduced['user_description']
  df_reduced['name_plus_desp'] = df_reduced['name_plus_desp'].astype(str)
  df_reduced.head() 
  
  #dt = df_reduced['name_plus_desp'].apply(cleaning)
  df_reduced['name_plus_desp_clean'] = df_reduced['name_plus_desp'].apply(cleaning)

  
  #print(df_reduced['name_plus_desp_clean'])
  print("\n")
  
  # word_count = Counter(" ".join(dt).split()).most_common(10)
  # word_frequency = pd.DataFrame(word_count, columns = ['Word', 'Frequency'])
  # print(word_frequency)

  df_reduced['new_col2'] = df_reduced.apply(lambda row: func2(row['name_plus_desp_clean'], row['user_verified']), axis =1)
  print(df_reduced['new_col2'].value_counts())
  
  path2 = "/content/drive/MyDrive/IDS 506 Healthcare Analytics/506 Project/Further_filtering"

  #os.makedirs(path, exist_ok=False)
  isExist = os.path.exists(path2)
  if not isExist:
  
    # Create a new directory because it does not exist 
    os.makedirs(path2)
    print("The new directory is created!")
  dest_path = "/content/drive/MyDrive/IDS 506 Healthcare Analytics/506 Project/Further_filtering/df_ff_" + d_str + ".csv"
  df_reduced.to_csv(dest_path)
# Out:
# DatetimeIndex(['2021-11-21', '2021-11-22', '2021-11-23', '2021-11-24',
#                '2021-11-25', '2021-11-26', '2021-11-27', '2021-11-28',
#                '2021-11-29', '2021-11-30', '2021-12-01', '2021-12-02',
#                '2021-12-03', '2021-12-04', '2021-12-05', '2021-12-06',
#                '2021-12-07', '2021-12-08', '2021-12-09', '2021-12-10',
#                '2021-12-11', '2021-12-12', '2021-12-13', '2021-12-14',
#                '2021-12-15', '2021-12-16', '2021-12-17', '2021-12-18',
#                '2021-12-19', '2021-12-20', '2021-12-21', '2021-12-22',
#                '2021-12-23', '2021-12-24', '2021-12-25', '2021-12-26',
#                '2021-12-27', '2021-12-28', '2021-12-29', '2021-12-30',
#                '2021-12-31', '2022-01-01', '2022-01-02', '2022-01-03',
#                '2022-01-04', '2022-01-05', '2022-01-06', '2022-01-07',
#                '2022-01-08', '2022-01-09', '2022-01-10', '2022-01-11',
#                '2022-01-12', '2022-01-13', '2022-01-14', '2022-01-15',
#                '2022-01-16', '2022-01-17', '2022-01-18', '2022-01-19',
#                '2022-01-20', '2022-01-21', '2022-01-22', '2022-01-23',
#                '2022-01-24', '2022-01-25', '2022-01-26', '2022-01-27',
#                '2022-01-28', '2022-01-29', '2022-01-30', '2022-01-31'],
#               dtype='datetime64[ns]', freq='D')
# 11212021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ind    41800
# org     2374
# Name: new_col2, dtype: int64
# 11222021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    51395
# org     3536
# Name: new_col2, dtype: int64
# 11232021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    47402
# org     3407
# Name: new_col2, dtype: int64
# 11242021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    49517
# org     3118
# Name: new_col2, dtype: int64
# 11252021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    41806
# org     2377
# Name: new_col2, dtype: int64
# 11262021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    91013
# org     6009
# Name: new_col2, dtype: int64
# 11272021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    74308
# org     4406
# Name: new_col2, dtype: int64
# 11282021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    68525
# org     4080
# Name: new_col2, dtype: int64
# 11292021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    72585
# org     5413
# Name: new_col2, dtype: int64
# 11302021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    76052
# org     5570
# Name: new_col2, dtype: int64
# 12012021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    87094
# org     5784
# Name: new_col2, dtype: int64
# 12022021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    88326
# org     5395
# Name: new_col2, dtype: int64
# 12032021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    67443
# org     4703
# Name: new_col2, dtype: int64
# 12042021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    50951
# org     3197
# Name: new_col2, dtype: int64
# 12052021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    50986
# org     3002
# Name: new_col2, dtype: int64
# 12062021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    68523
# org     4181
# Name: new_col2, dtype: int64
# 12072021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    58255
# org     4019
# Name: new_col2, dtype: int64
# 12082021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    75175
# org     4292
# Name: new_col2, dtype: int64
# 12092021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    65705
# org     4639
# Name: new_col2, dtype: int64
# 12102021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    52850
# org     3828
# Name: new_col2, dtype: int64
# 12112021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    34566
# org     2057
# Name: new_col2, dtype: int64
# 12122021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    51676
# org     3157
# Name: new_col2, dtype: int64
# 12132021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    68264
# org     4862
# Name: new_col2, dtype: int64
# 12142021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    84513
# org     5836
# Name: new_col2, dtype: int64
# 12152021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    88747
# org     6147
# Name: new_col2, dtype: int64
# 12162021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    84857
# org     5823
# Name: new_col2, dtype: int64
# 12172021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    90460
# org     6332
# Name: new_col2, dtype: int64
# 12182021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    80338
# org     4347
# Name: new_col2, dtype: int64
# 12192021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    73125
# org     4053
# Name: new_col2, dtype: int64
# 12202021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    95085
# org     6854
# Name: new_col2, dtype: int64
# 12212021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    94775
# org     7119
# Name: new_col2, dtype: int64
# 12222021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    57701
# org     4654
# Name: new_col2, dtype: int64
# 12232021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    87922
# org     6723
# Name: new_col2, dtype: int64
# 12242021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    191759
# org     13467
# Name: new_col2, dtype: int64
# 12252021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    48811
# org     3178
# Name: new_col2, dtype: int64
# 12262021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    55869
# org     3718
# Name: new_col2, dtype: int64
# 12272021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    84899
# org     6076
# Name: new_col2, dtype: int64
# 12282021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    96137
# org     6682
# Name: new_col2, dtype: int64
# 12292021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    98569
# org     6972
# Name: new_col2, dtype: int64
# 12302021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    109112
# org      6801
# Name: new_col2, dtype: int64
# 12312021
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    82980
# org     4388
# Name: new_col2, dtype: int64
# 01012022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    65020
# org     3731
# Name: new_col2, dtype: int64
# 01022022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    77743
# org     4752
# Name: new_col2, dtype: int64
# 01032022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    90970
# org     6813
# Name: new_col2, dtype: int64
# 01042022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    107513
# org      7547
# Name: new_col2, dtype: int64
# 01052022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    101483
# org      7281
# Name: new_col2, dtype: int64
# 01062022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    65724
# org     5205
# Name: new_col2, dtype: int64
# 01072022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    110044
# org      8526
# Name: new_col2, dtype: int64
# 01082022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    85357
# org     5523
# Name: new_col2, dtype: int64
# 01092022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    79093
# org     4818
# Name: new_col2, dtype: int64
# 01102022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    94049
# org     6996
# Name: new_col2, dtype: int64
# 01112022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    97527
# org     7012
# Name: new_col2, dtype: int64
# 01122022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    95631
# org     6664
# Name: new_col2, dtype: int64
# 01132022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    96927
# org     6803
# Name: new_col2, dtype: int64
# 01142022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    81476
# org     5905
# Name: new_col2, dtype: int64
# 01152022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    61407
# org     3758
# Name: new_col2, dtype: int64
# 01162022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    55234
# org     3324
# Name: new_col2, dtype: int64
# 01172022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    61570
# org     4625
# Name: new_col2, dtype: int64
# 01182022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    77712
# org     5853
# Name: new_col2, dtype: int64
# 01192022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    77323
# org     6003
# Name: new_col2, dtype: int64
# 01202022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    59684
# org     4548
# Name: new_col2, dtype: int64
# 01212022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    63409
# org     5002
# Name: new_col2, dtype: int64
# 01222022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    52620
# org     3513
# Name: new_col2, dtype: int64
# 01232022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    49291
# org     3056
# Name: new_col2, dtype: int64
# 01242022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    66294
# org     4351
# Name: new_col2, dtype: int64
# 01252022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    65244
# org     4636
# Name: new_col2, dtype: int64
# 01262022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    58275
# org     4076
# Name: new_col2, dtype: int64
# 01272022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    63776
# org     4136
# Name: new_col2, dtype: int64
# 01282022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    60319
# org     3932
# Name: new_col2, dtype: int64
# 01292022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    47464
# org     3062
# Name: new_col2, dtype: int64
# 01302022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    44354
# org     2660
# Name: new_col2, dtype: int64
# 01312022
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
#
# ind    66021
# org     4744
# Name: new_col2, dtype: int64

# %%
p = "/content/drive/MyDrive/IDS 506 Healthcare Analytics/506 Project/Further Filtered/df_ff_12222021.csv"
df_p = pd.read_csv(p, engine='python')

# %%
df_p.head(100)
# Out:
#     Unnamed: 0 coordinates                      created_at  \
# 0            0         NaN  Wed Dec 22 05:03:25 +0000 2021
# 1            1         NaN  Wed Dec 22 05:04:34 +0000 2021
# 2            2         NaN  Wed Dec 22 05:03:25 +0000 2021
# 3            3         NaN  Wed Dec 22 05:04:07 +0000 2021
# 4            4         NaN  Wed Dec 22 05:04:00 +0000 2021
# ..         ...         ...                             ...
# 95          95         NaN  Wed Dec 22 05:05:25 +0000 2021
# 96          96         NaN  Wed Dec 22 05:04:52 +0000 2021
# 97          97         NaN  Wed Dec 22 05:05:18 +0000 2021
# 98          98         NaN  Wed Dec 22 05:05:45 +0000 2021
# 99          99         NaN  Wed Dec 22 05:05:04 +0000 2021
#
#                                     hashtags                       place  \
# 0                                        NaN                         NaN
# 1                                        NaN                         NaN
# 2                                        NaN                         NaN
# 3                                        NaN                         NaN
# 4                                        NaN                         NaN
# ..                                       ...                         ...
# 95                                       NaN                         NaN
# 96                                   COVID19                         NaN
# 97                                       NaN  Barrow-in-Furness, England
# 98  trump vaccinated vaccination coronavirus                         NaN
# 99                                       NaN                         NaN
#
#                                                source  \
# 0   <a href="http://twitter.com/download/iphone" r...
# 1   <a href="http://twitter.com/download/iphone" r...
# 2   <a href="http://twitter.com/download/iphone" r...
# 3   <a href="http://twitter.com/download/iphone" r...
# 4   <a href="https://mobile.twitter.com" rel="nofo...
# ..                                                ...
# 95  <a href="http://publicize.wp.com/" rel="nofoll...
# 96  <a href="http://twitter.com/download/iphone" r...
# 97  <a href="http://twitter.com/download/android" ...
# 98  <a href="http://twitter.com/download/android" ...
# 99  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                      user_description  \
# 0                                                 NaN
# 1   ❌Red Pill❌ 🇺🇸. USAF Vet💪🏽Wife 🙋🏽‍♀️Mom 👫🏽 RN👩🏽...
# 2   Advertising/Tech Professional | Musician | Woo...
# 3                                                 NaN
# 4   ICU physician & researcher, interests: EOL/pal...
# ..                                                ...
# 95  Tech Pauls News provides you the best News exp...
# 96  . 🌕 * . 🌍 * * . ☄️ • * • . . . 🪐 . * ✨ * 💫 * ....
# 97  LIFE with @jollibird & Jolliffe tribe,brillian...
# 98  "There are no accidents; just an action, react...
# 99  NZ, USA. In love with democracy. #SlavaUkraini...
#
#                                         user_name                   id  \
# 0                                          Mark T  1473519520673374209
# 1                                    💣Atom Bomb 💣  1473519812206804997
# 2                                     Tyler David  1473519522514673664
# 3                                     C E L E N A  1473519696796430338
# 4                         Thanh Neville, MD, MSHS  1473519668136591364
# ..                                            ...                  ...
# 95                                Tech Pauls News  1473520024665182211
# 96                                          Sarah  1473519889465978880
# 97                                 Geoff Jolliffe  1473519998291300354
# 98                                DudeOneToNothin  1473520110660771842
# 99  💛Hurricane Watcher💙 - Go **** yourself, Putin  1473519939470249984
#
#    user_screen_name                           user_urls user_verified  \
# 0       mtucksports                                 NaN         False
# 1       atom_jarvis                                 NaN         False
# 2         tedavid93                                 NaN         False
# 3     CelenaRenee_1                                 NaN         False
# 4     thanh_neville  http://www.uclahealth.org/3wishes/         False
# ..              ...                                 ...           ...
# 95    TechPaulsnews           http://news.techpauls.com         False
# 96   hetbazileharas                                 NaN         False
# 97           MI5GCJ                                 NaN         False
# 98  dudeonetonothin   https://linktr.ee/DudeOneToNothin         False
# 99  FreedomFriesInc                                 NaN         False
#
#                                                  text ind_org  \
# 0   @quachelsey And then go check out one of the o...     ind
# 1   @hotdishpotluck @AaronParnas Owl… covid19 is e...     ind
# 2   Holy crap.\nThis could change everything. http...     ind
# 3   Should’ve never been instituted in the first p...     ind
# 4   I can almost hear the pleading behind this sta...     ind
# ..                                                ...     ...
# 95  No reason to pause, Covid-19 vaccines are work...     ind
# 96  Y’all I’m a fucking idiot (who is vaccinated) ...     ind
# 97  Simple\nAvoid large gatherings  and contact wi...     ind
# 98  .@AaronRodgers12 u know ur hero #trump is #vac...     ind
# 99  @Studio2bA @RWPUSA There is info about it here...     ind
#
#                                        name_plus_desp  \
# 0                                                 NaN
# 1   💣Atom Bomb 💣 ❌Red Pill❌ 🇺🇸. USAF Vet💪🏽Wife 🙋🏽‍...
# 2   Tyler David Advertising/Tech Professional | Mu...
# 3                                                 NaN
# 4   Thanh Neville, MD, MSHS ICU physician & resear...
# ..                                                ...
# 95  Tech Pauls News Tech Pauls News provides you t...
# 96  Sarah . 🌕 * . 🌍 * * . ☄️ • * • . . . 🪐 . * ✨ *...
# 97  Geoff Jolliffe LIFE with @jollibird & Jolliffe...
# 98  DudeOneToNothin "There are no accidents; just ...
# 99  💛Hurricane Watcher💙 - Go **** yourself, Putin ...
#
#                                  name_plus_desp_clean new_col2
# 0                                                 NaN      ind
# 1       atom bomb red pill usaf vetwife mom rn 605206      ind
# 2   tyler david advertisingtech professional music...      ind
# 3                                                 NaN      ind
# 4   thanh neville md mshs icu physician researcher...      ind
# ..                                                ...      ...
# 95  tech pauls news tech pauls news provides best ...      org
# 96                                              sarah      ind
# 97  geoff jolliffe life jolliffe tribebrilliant ba...      ind
# 98  dudeonetonothin accidents action reactions con...      ind
# 99  hurricane watcher go putin nz usa love democra...      ind
#
# [100 rows x 17 columns]

# %%
'''

def func2(val1, val2):
    for word in uniq_list:
        if (word in val1):     # may use val2 ie user_verified status for additional filtering
            return "org"
        else:
            return "ind"

df_reduced['new_col2'] = df_reduced.apply(lambda row: func2(row['name_plus_desp_clean'], row['user_verified']), axis =1)
'''
